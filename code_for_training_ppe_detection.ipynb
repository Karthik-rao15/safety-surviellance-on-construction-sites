# %% [markdown]
# Steps to follow
#
# 1.Change Runtime to GPU
#
# 2.Plug in google drive
#
# 3.Create a folder in drive and change directory
#
# 4.load datafrom roboflow
#
# 5.pip install ultralytics
#
# 6.Train the model using data

# %%
# !pwd
# Out:
# /content

# %%
cd drive/MyDrive
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive'
# /content

# %%
# !mkdir ppe
# Out:
# mkdir: cannot create directory ‘ppe’: File exists

# %%
cd ppe
# Out:
# /content/ppe

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="MILbT4Pt3kAMw0Qc3iVz")
project = rf.workspace("ppe9extra").project("ppe-vest3")
dataset = project.version(3).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.196, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to ppe-vest3-3 in yolov8:: 100%|██████████| 1021/1021 [00:00<00:00, 8433.08it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 9.6 MB/s eta 0:00:00
# ...

# %%
# !yolo mode=train model=yolov8n.pt data='/content/drive/MyDrive/ppe/ppe-vest3-3/data.yaml' epochs=100
# Out:
# /bin/bash: line 1: yolo: command not found
